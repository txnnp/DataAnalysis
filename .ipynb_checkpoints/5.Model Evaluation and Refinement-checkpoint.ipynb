# %% [markdown]
# # <center>Model Evaluation and Refinement</center>

# %% [markdown]
# This dataset was hosted on IBM Cloud object.

# %%
import pandas as pd
import numpy as np

# Import cleaned data 
path = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/module_5_auto.csv'
df = pd.read_csv(path)

# %%
df.to_csv('D:\Github\DataAnalysis\Dataset\module_5_auto.csv')

# %% [markdown]
# **First, let's only use numeric data:**

# %%
df = df._get_numeric_data()
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  symboling  normalized-losses  wheel-base  \
# 0           0             0          3                122        88.6
# 1           1             1          3                122        88.6
# 2           2             2          1                122        94.5
# 3           3             3          2                164        99.8
# 4           4             4          2                164        99.4
#
#      length     width  height  curb-weight  engine-size  ...  stroke  \
# 0  0.811148  0.890278    48.8         2548          130  ...    2.68
# 1  0.811148  0.890278    48.8         2548          130  ...    2.68
# 2  0.822681  0.909722    52.4         2823          152  ...    3.47
# 3  0.848630  0.919444    54.3         2337          109  ...    3.40
# 4  0.848630  0.922222    54.3         2824          136  ...    3.40
#
#    compression-ratio  horsepower  peak-rpm  city-mpg  highway-mpg    price  \
# ...

# %% [markdown]
# Libraries for plotting (%%capture for avoid to show output):

# %%
# %%capture
# !pip install ipywidgets

# %%
from ipywidgets import interact, interactive, fixed, interact_manual

# %% [markdown]
# ## 1. Create a Functions for Plotting
# We should remember how to define these functions (seaborn will update displot to hisplot).

# %%
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
    width = 12
    height = 10
    plt.figure(figsize=(width, height))
    ax1 = sns.distplot(RedFunction, hist=False, color="r", label=RedName)
    ax2 = sns.distplot(BlueFunction, hist=False, color="b", label=BlueName, ax=ax1)

    plt.title(Title)
    plt.xlabel('Price (in dollars)')
    plt.ylabel('Proportion of Cars')

    plt.show()
    plt.close()

# %%
def PollyPlot(xtrain, xtest, y_train, y_test, lr,poly_transform):
    width = 12
    height = 10
    plt.figure(figsize=(width, height))
    
    
    #training data 
    #testing data 
    # lr:  linear regression object 
    #poly_transform:  polynomial transformation object 
 
    xmax=max([xtrain.values.max(), xtest.values.max()])

    xmin=min([xtrain.values.min(), xtest.values.min()])

    x=np.arange(xmin, xmax, 0.1)


    plt.plot(xtrain, y_train, 'ro', label='Training Data')
    plt.plot(xtest, y_test, 'go', label='Test Data')
    plt.plot(x, lr.predict(poly_transform.fit_transform(x.reshape(-1, 1))), label='Predicted Function')
    plt.ylim([-10000, 60000])
    plt.ylabel('Price')
    plt.legend()

# %% [markdown]
# ## 2. Part 1: Training and Testing
# An important step in testing your model is to **split your data into training and testing data**. We will place the target data **price** in a separate dataframe **y_data**:

# %%
y_data = df['price']

# %% [markdown]
# Drop price data in dataframe **x_data**:

# %%
x_data = df.drop('price',axis=1)

# %% [markdown]
# Now, we **randomly split** our data into training and testing data using the function `train_test_split`.

# %%
from sklearn.model_selection import train_test_split

# We can should the size of testing data (from 100%)
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.10, random_state=1)


print("number of test samples :", x_test.shape[0])
print("number of training samples:",x_train.shape[0])
# Out:
# number of test samples : 21
# number of training samples: 180

# %% [markdown]
# The **test_size** parameter sets the proportion of data that is split into the testing set. In the above, the testing set is 10% of the total dataset.

# %% [markdown]
# Use the function "train_test_split" to split up the dataset such that 40% of the data samples will be utilized for testing. Set the parameter "random_state" equal to zero. The output of the function should be the following:  "x_train1" , "x_test1", "y_train1" and  "y_test1".

# %%
x_train1, x_test1, y_train1, y_test1 = train_test_split(x_data, y_data, test_size=0.40, random_state=0)

print('Number of test samples: ', x_test1.shape[0])
print('Number of training samples: ', x_train1.shape[0])
# Out:
# Number of test samples:  81
# Number of training samples:  120

# %% [markdown]
# Let's import **LinearRegression** from the module **linear_model**.

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# We **create a Linear Regression object**:

# %%
lre = LinearRegression()

# %% [markdown]
# We **fit the model using the feature "horsepower"**:

# %%
lre.fit(x_train[['horsepower']], y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Let's **calculate the R-square on the test data**:

# %%
lre.score(x_test[['horsepower']], y_test)
# Out:
# 0.3635875575078824

# %% [markdown]
# We can see the R-square is much smaller using the test data compared to the training data.

# %%
lre.score(x_train[['horsepower']], y_train)
# Out:
# 0.6619724197515103

# %% [markdown]
# Find the R-square on the **test data** using 40% of the dataset for testing.

# %%
x_train1, x_test1, y_train1, y_test1 = train_test_split(x_data, y_data, test_size=0.4, random_state=0)
lre.fit(x_train1[['horsepower']], y_train1)
lre.score(x_test1[['horsepower']], y_test1)
# Out:
# 0.7139364665406973

# %% [markdown]
# Sometimes you do not have sufficient testing data; as a result, you may want to perform **cross-validation**. Let's go over several methods that you can use for cross-validation.

# %% [markdown]
# ## 3. Cross-Validation Score

# %% [markdown]
# Let's import **model_selection** from the module **cross_val_score**.

# %%
from sklearn.model_selection import cross_val_score

# %% [markdown]
# We input the object, the feature ("horsepower"), and the target data (y_data). The parameter 'cv' determines the number of folds. In this case, it is 4.
# ![image](http://ethen8181.github.io/machine-learning/model_selection/img/kfolds.png)
#
# In this picture cv=5;

# %%
Rcross = cross_val_score(lre, x_data[['horsepower']], y_data, cv=4)

# %% [markdown]
# **The default scoring is R-square**. Each element in the array has the average R-square value for the fold:

# %%
Rcross
# Out:
# array([0.7746232 , 0.51716687, 0.74785353, 0.04839605])

# %% [markdown]
# We can **calculate the average and standard deviation of our estimate**:

# %%
print("The mean of the folds are", Rcross.mean(), "and the standard deviation is" , Rcross.std())
# Out:
# The mean of the folds are 0.522009915042119 and the standard deviation is 0.2911839444756029

# %% [markdown]
# We can use negative squared error as a score by setting the parameter `scoring` metric to `'neg_mean_squared_error'`.

# %%
-1 * cross_val_score(lre,x_data[['horsepower']], y_data,cv=4,scoring='neg_mean_squared_error')
# Out:
# array([20254142.84026704, 43745493.2650517 , 12539630.34014931,
#        17561927.72247591])

# %% [markdown]
# **Calculate the average R-square using two folds (cv=2)**, then find the average R-square for the second fold utilizing the "horsepower" feature:

# %%
Rcross1 = cross_val_score(lre, x_data[['horsepower']], y_data, cv=2)
Rcross1
# Out:
# array([0.59015621, 0.44319613])

# %%
print(f"The Average R-square of 2 folds are {Rcross1.mean()}")
# Out:
# The Average R-square of 2 folds are 0.5166761697127429

# %% [markdown]
# You can also use the function `cross_val_predict` to predict the output. The function splits up the data into the specified number of folds, with one fold for testing and the other folds are used for training.
# #### First, import the function:

# %%
from sklearn.model_selection import cross_val_predict

# %% [markdown]
# We input the object, the feature **"horsepower"**, and the target data **y_data**. The parameter 'cv' determines the number of folds. In this case, it is 4. We can produce an output:

# %%
yhat = cross_val_predict(lre, x_data[['horsepower']], y_data,cv=4)
yhat[0:5]
# Out:
# array([14141.63807508, 14141.63807508, 20814.29423473, 12745.03562306,
#        14762.35027598])

# %% [markdown]
# ## 4. Part 2: Overfitting, Underfitting and Model Selection
# It turns out that the test data, sometimes referred to as the "out of sample data", is a much better measure of how well your model performs in the real world.  One reason for this is overfitting.
#
# Let's go over some examples. It turns out these differences are more apparent in Multiple Linear Regression (MLR) and Polynomial Regression (PR) so we will explore overfitting in that context.

# %% [markdown]
# Let's create Multiple Linear Regression objects and train the model using **'horsepower'**, **'curb-weight'**, **'engine-size'** and **'highway-mpg'** as features.

# %%
lr = LinearRegression()
lr.fit(x_train[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']], y_train)
# Out:
# LinearRegression()

# %% [markdown]
# **Prediction using training data:**

# %%
yhat_train = lr.predict(x_train[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']])
yhat_train[0:5]
# Out:
# array([ 7426.6731551 , 28323.75090803, 14213.38819709,  4052.34146983,
#        34500.19124244])

# %% [markdown]
# **Prediction using test data:**

# %%
yhat_test = lr.predict(x_test[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']])
yhat_test[0:5]
# Out:
# array([11349.35089149,  5884.11059106, 11208.6928275 ,  6641.07786278,
#        15565.79920282])

# %% [markdown]
# Let's perform some model evaluation using our training and testing data separately.
#
# **First, we import the seaborn and matplotlib library for plotting.**

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# Let's **examine the distribution of the predicted values of the training data.**

# %%
Title = 'Distribution Plot of Predicted Value Using Training Data vs Training Data Distribution'
DistributionPlot(y_train, yhat_train, "Actual Values (Train)", "Predicted Values (Train)", Title)
# Red function : y_train
# Blue function : yhat_train
# Out:
# C:\Users\tinna\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\tinna\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Figure 1: Plot of predicted values using the training data compared to the actual values of the training data.

# %% [markdown]
# So far, the model seems to be doing well in learning from the training dataset. But what happens when the model encounters new data from the testing dataset? When the model generates new values from the test data, we see the distribution of the predicted values is much different from the actual target values.

# %%
Title='Distribution Plot of Predicted Value Using Test Data vs Data Distribution of Test Data'
DistributionPlot(y_test, yhat_test, "Actual Values (Test)", "Predicted Values (Test)", Title)
# Red function : y_test
# Blue function : yhat_test
# Out:
# C:\Users\tinna\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\tinna\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Figure 2: Plot of predicted value using the test data compared to the actual values of the test data.

# %% [markdown]
# Comparing Figure 1 and Figure 2, it is evident that the distribution of the test data in Figure 1 is much better at fitting the data. This difference in Figure 2 is apparent in the range of 5000 to 15,000. This is where the shape of the distribution is extremely different. Let's see if **polynomial regression** also exhibits a drop in the prediction accuracy when analysing the test dataset.

# %%
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# #### Overfitting
# Overfitting occurs when the model fits the noise, but not the underlying process. Therefore, when testing your model using the test set, your model does not perform as well since it is modelling noise, not the underlying process that generated the relationship. Let's create a degree 5 polynomial model.

# %% [markdown]
# Let's use 55 percent of the data for training and the rest for testing:

# %%
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.45, random_state=0)

# %% [markdown]
# We will perform a degree 5 polynomial transformation on the feature **'horsepower'**.

# %%
pr = PolynomialFeatures(degree=5)
x_train_pr = pr.fit_transform(x_train[['horsepower']])
x_test_pr = pr.fit_transform(x_test[['horsepower']])
pr
# Out:
# PolynomialFeatures(degree=5)

# %% [markdown]
# Now, **let's create a Linear Regression model "poly" and train it.**

# %%
poly = LinearRegression()
poly.fit(x_train_pr, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# We can see the output of our model using the method `predict`. We assign the values to **yhat**.

# %%
yhat = poly.predict(x_test_pr)
yhat[0:5]
# Out:
# array([ 6728.70501896,  7308.02845162, 12213.7843307 , 18893.19108677,
#        19995.88963424])

# %% [markdown]
# Let's take the **first five predicted values and compare it to the actual targets.**

# %%
print("Predicted values:", yhat[0:4])
print("True values:", y_test[0:4].values)
# Out:
# Predicted values: [ 6728.70501896  7308.02845162 12213.7843307  18893.19108677]
# True values: [ 6295. 10698. 13860. 13499.]

# %% [markdown]
# We will use the function "PollyPlot" that we defined at the beginning of the lab to display the training data, testing data, and the predicted function.

# %%
PollyPlot(x_train[['horsepower']], x_test[['horsepower']], y_train, y_test, poly,pr)

# %% [markdown]
# Figure 3: A polynomial regression model where **red dots represent training data**, **green dots represent test data**, and the **blue line represents the model prediction.**

# %% [markdown]
# We see that the estimated function appears to track the data but around 200 horsepower, the function begins to diverge from the data points.

# %% [markdown]
# **R-square of the training data:**

# %%
poly.score(x_train_pr, y_train)
# Out:
# 0.5567716902635091

# %% [markdown]
# **R-square of the test data:**

# %%
poly.score(x_test_pr, y_test)
# Out:
# -29.871418859187518

# %% [markdown]
# We see the R-square for the **training data is 0.5567** while the R-square on **the test data was -29.87.**
# - The lower the R-square, the worse the model.
# - **A negative R-square** is a sign of overfitting.

# %% [markdown]
# Let's see how the R-square changes on the test data for different order polynomials and then plot the results:

# %%
Rsqu_test = []

order = [1, 2, 3, 4]
for n in order:
    pr = PolynomialFeatures(degree=n)
    
    x_train_pr = pr.fit_transform(x_train[['horsepower']])
    
    x_test_pr = pr.fit_transform(x_test[['horsepower']])    
    
    lr.fit(x_train_pr, y_train)
    
    Rsqu_test.append(lr.score(x_test_pr, y_test))

plt.plot(order, Rsqu_test)
plt.xlabel('order')
plt.ylabel('R^2')
plt.title('R^2 Using Test Data')
plt.text(3, 0.75, 'Maximum R^2 ')
# Out:
# Text(3, 0.75, 'Maximum R^2 ')

# %% [markdown]
# We see the R-square gradually increases until an order three polynomial is used. Then, the R-square dramatically decreases at an order four polynomial.

# %% [markdown]
# The following function will be used in the next section. Please run the cell below.

# %%
def f(order, test_data):
    x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=test_data, random_state=0)
    pr = PolynomialFeatures(degree=order)
    x_train_pr = pr.fit_transform(x_train[['horsepower']])
    x_test_pr = pr.fit_transform(x_test[['horsepower']])
    poly = LinearRegression()
    poly.fit(x_train_pr,y_train)
    PollyPlot(x_train[['horsepower']], x_test[['horsepower']], y_train,y_test, poly, pr)

# %% [markdown]
# The following interface allows you to experiment with different polynomial orders and different amounts of data. (can be slide)

# %%
interact(f, order=(0, 6, 1), test_data=(0.05, 0.95, 0.05))
# Out:
# interactive(children=(IntSlider(value=3, description='order', max=6), FloatSlider(value=0.45, description='tes…
# <function __main__.f(order, test_data)>

# %% [markdown]
# We can perform polynomial transformations with more than one feature. Create a "PolynomialFeatures" object "pr1" of degree two.

# %%
pr1 = PolynomialFeatures(degree=2)

# %% [markdown]
# Transform the training and testing samples for the features 'horsepower', 'curb-weight', 'engine-size' and 'highway-mpg'. by using the method `fit_transform`.

# %%
x_training_pr1 = pr1.fit_transform(x_train[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']])
x_testing_pr1 = pr1.fit_transform(x_test[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']])

# %% [markdown]
# <!-- The answer is below:
#
# x_train_pr1=pr.fit_transform(x_train[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']])
# x_test_pr1=pr.fit_transform(x_test[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']])
#
# -->

# %% [markdown]
# How many dimensions does the new feature have? Hint: use the attribute `shape`

# %%
x_training_pr1.shape # There are now 15 features
# Out:
# (110, 15)

# %% [markdown]
# Create a linear regression model "poly1". Train the object using the method "fit" using the polynomial features.

# %%
poly1 = LinearRegression()
poly1.fit(x_training_pr1, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Use the method `predict` to **predict an output on the polynomial features**, then use the function **"DistributionPlot"** to display the distribution of the predicted test output vs. the actual test data.

# %%
yhat_test1 = poly1.predict(x_testing_pr1)

Title='Distribution  Plot of  Predicted Value Using "Test Data vs Data Distribution of Test Data"'

DistributionPlot(y_test, yhat_test1, "Actual Values (Test)", "Predicted Values (Test)", Title)
# Out:
# C:\Users\tinna\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\tinna\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Using the distribution plot above, describe (in words) the two regions where the predicted prices are less accurate than the actual prices.

# %% [markdown]
# The predicted value (Blue) is higher than actual value (Red) for cars where the price 10,000 range, Conversely the predicted price is lower than the price cost in the 30,000 to 40,000 range. As such the model is not as accurate in these ranges.

# %% [markdown]
# ## 5. Part 3: Ridge Regression
# In this section, we will review Ridge Regression and see how the parameter alpha changes the model. Just a note, here our test data will be used as validation data.

# %% [markdown]
# Let's perform a degree 2 polynomial transformation on our data.

# %%
pr = PolynomialFeatures(degree=2)
x_train_pr = pr.fit_transform(x_train[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg','normalized-losses','symboling']])
x_test_pr = pr.fit_transform(x_test[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg','normalized-losses','symboling']])

# %% [markdown]
# Let's import **Ridge** from the module **linear models**.

# %%
from sklearn.linear_model import Ridge

# %% [markdown]
# Let's create a **Ridge regression object**, and setting the regularization parameter (alpha) to 0.1

# %%
RigeModel = Ridge(alpha=1)

# %% [markdown]
# Like regular regression, you can fit the model using the method `fit`.

# %%
RigeModel.fit(x_train_pr, y_train)
# Out:
# Ridge(alpha=1)

# %% [markdown]
# Similarly, **you can obtain a prediction:**

# %%
yhat = RigeModel.predict(x_test_pr)

# %% [markdown]
# Let's **compare the first five predicted samples to the test set**:

# %%
print('predicted:', yhat[0:4])
print('test set :', y_test[0:4].values)
# Out:
# predicted: [ 6570.82441941  9636.24891471 20949.92322737 19403.60313255]
# test set : [ 6295. 10698. 13860. 13499.]

# %% [markdown]
# We select the value of alpha that minimizes the test error. To do so, we can use a for loop. We have also created a progress bar to see how many iterations we have completed so far.

# %%
# Use for loop to minimizes the test error
from tqdm import tqdm

Rsqu_test = []
Rsqu_train = []
dummy1 = []
Alpha = 10 * np.array(range(0,1000))
pbar = tqdm(Alpha)

for alpha in pbar:
    RigeModel = Ridge(alpha=alpha) 
    RigeModel.fit(x_train_pr, y_train)
    test_score, train_score = RigeModel.score(x_test_pr, y_test), RigeModel.score(x_train_pr, y_train)
    
    pbar.set_postfix({"Test Score": test_score, "Train Score": train_score})

    Rsqu_test.append(test_score)
    Rsqu_train.append(train_score)
# Out:
# 100%|████████████████████████████████████████| 1000/1000 [00:04<00:00, 244.47it/s, Test Score=0.564, Train Score=0.859]

# %% [markdown]
# We can **plot out the value of R-square for different alphas:**

# %%
width = 12
height = 10
plt.figure(figsize=(width, height))

plt.plot(Alpha,Rsqu_test, label='validation data  ')
plt.plot(Alpha,Rsqu_train, 'r', label='training Data ')
plt.xlabel('alpha')
plt.ylabel('R^2')
plt.legend()

# %% [markdown]
# **Figure 4**: The blue line represents the R-square of the validation data, and the red line represents the R-square of the training data. The x-axis represents the different values of Alpha.

# %% [markdown]
# Here the model is built and tested on the same data, so the training and test data are the same.
# - The **red line** in Figure 4 represents the R-square of the training data. **As alpha increases the R-square decreases**. Therefore, as alpha increases, the model performs worse on the training data.
# - The **blue line** represents the R-square on the validation data. **As the value for alpha increases, the R-square increases and converges at a point.**

# %% [markdown]
# Perform Ridge regression. **Calculate the R-square using the polynomial features**, use the training data to train the model and use the test data to test the model. The parameter alpha should be set to 10.

# %%
RigdeModel1 = Ridge(alpha=10)
RigdeModel1.fit(x_train_pr, y_train)
RigdeModel1.score(x_test_pr, y_test)
# Out:
# 0.5418576440207269

# %% [markdown]
# ## 6. Part 4: Grid Search
# **The term alpha is a hyperparameter.** Sklearn has the class `GridSearchCV` to make the process of finding the best hyperparameter simpler.

# %% [markdown]
# Let's import `GridSearchCV` from  the module **model_selection**.

# %%
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# We **create a dictionary of parameter values:**

# %%
parameters1= [{'alpha': [0.001,0.1,1, 10, 100, 1000, 10000, 100000, 100000]}]
parameters1
# Out:
# [{'alpha': [0.001, 0.1, 1, 10, 100, 1000, 10000, 100000, 100000]}]

# %% [markdown]
# **Create a Ridge regression object:**

# %%
RR = Ridge()
RR
# Out:
# Ridge()

# %% [markdown]
# **Create a ridge grid search object:**

# %%
Grid1 = GridSearchCV(RR, parameters1, cv=4)

# %% [markdown]
# In order to avoid a deprecation warning due to the iid parameter, we set the value of iid to "None".
# **Fit the model:**

# %%
Grid1.fit(x_data[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']], y_data)
# Out:
# GridSearchCV(cv=4, estimator=Ridge(),
#              param_grid=[{'alpha': [0.001, 0.1, 1, 10, 100, 1000, 10000, 100000,
#                                     100000]}])

# %% [markdown]
# The object finds the best parameter values on the validation data. **We can obtain the estimator with the best parameters and assign it to the variable BestRR as follows:**

# %%
BestRR = Grid1.best_estimator_
BestRR
# Out:
# Ridge(alpha=10000)

# %% [markdown]
# **We now test our model on the test data:**

# %%
BestRR.score(x_test[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']], y_test)
# Out:
# 0.8411649831036149

# %% [markdown]
# Perform a grid search for the alpha parameter and the normalization parameter, then find the best values of the parameters:

# %%
from sklearn.pipeline import make_pipeline
Grid2 = make_pipeline(StandardScaler(with_mean=False), Ridge())

parameters2 = [{'alpha': [0.001,0.1,1, 10, 100, 1000,10000,100000,100000],'normalize':[True,False]} ]
Grid2 = GridSearchCV(Ridge(), parameters2, cv=4)
Grid2.fit(x_data[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']], y_data)
Grid2.best_estimator_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7428/3632943662.py in <module>
#       1 from sklearn.pipeline import make_pipeline
# ----> 2 Grid2 = make_pipeline(StandardScaler(with_mean=False), Ridge())
#       3
#       4 parameters2 = [{'alpha': [0.001,0.1,1, 10, 100, 1000,10000,100000,100000],'normalize':[True,False]} ]
#       5 Grid2 = GridSearchCV(Ridge(), parameters2, cv=4)
#
# NameError: name 'StandardScaler' is not defined

# %% [markdown]
# ### The last cell is not complete now because of a variety of error.
